# %%
from graphs_functions import *
from RR_intervals_preprocessing import * 
from params import *
from tool_box import *

# %%
# RBF filtering on control with HR(170 - 210) 
plot_hist_comparison(params['file_path'], params)

# %%
# RBF filtering on control (170 < HR < 210) 
plot_tachogram_comparison(params['file_path'],params)

# %%
# MAF filtering on control  (Window Size = 21, limit_value = 20%)
plot_hist_comparison(params['file_path'], params)

# %%
# MAF filtering on control  (Window Size = 21, limit_value = 20%)
plot_tachogram_comparison(params['file_path'],params)

# %%
#QF filtering on control (limit_value_qf = 20%)
plot_hist_comparison(params['file_path'], params)

# %%
#QF filtering on control (limit_value_qf = 20%)
plot_tachogram_comparison(params['file_path'],params)

# %%
# RBF filtering on Propranolol 100 µM with HR(120 - 200) 
plot_hist_comparison(params['file_path'], params)

# %%
# RBF filtering on Propranolol 100 µM with HR(120 - 200) 
plot_tachogram_comparison(params['file_path'],params)

# %%
# MAF filtering on Propranolol 100 µM   (Window Size = 21, limit_value = 20%)
plot_hist_comparison(params['file_path'], params)

# %%
# MAF filtering on Propranolol 100 µM   (Window Size = 21, limit_value = 20%)
plot_tachogram_comparison(params['file_path'],params)

# %%
#QF filtering on Propranolol 100 µM  (limit_value_qf = 20%)
plot_hist_comparison(params['file_path'], params)

# %%
#QF filtering on Propranolol 100 µM  (limit_value_qf = 20%)
plot_tachogram_comparison(params['file_path'],params)
